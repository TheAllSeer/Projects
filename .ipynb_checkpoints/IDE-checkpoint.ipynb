# %%
from bs4 import BeautifulSoup
import requests
from lxml import etree
import pandas as pd
import pandasql as pds
import re
import numpy as np
import os
import matplotlib
import seaborn as sns
import sklearn
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.neural_network import MLPClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
import time
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
path_chrome = "D:/Programming/Python/chromedriver.exe"
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.options import Options
from selenium.common.exceptions import NoSuchElementException
from selenium.common.exceptions import WebDriverException

# %%
# url = "https://stackoverflow.com/questions/tagged/python"
# driver = webdriver.Chrome(path_chrome)
# driver.get(url)

# %%
# list of programming languages
driver = webdriver.Chrome(path_chrome)
driver.get("https://en.wikipedia.org/wiki/List_of_programming_languages")
languages = driver.find_elements(By.CSS_SELECTOR, 'div.div-col') # this makes a <list> of the <lists> of <programming languages> by <alphabet>
languages

# %%
langs = {}  # dictionary to store every language for each letter. this will be used to search them later in the tags.
# Out:
# "A.NET (A#/A sharp)\nA-0 System\nA+ (A plus)\nA++\nABAP\nABC\nABC ALGOL\nACC\nAccent (Rational Synergy)\nAce DASL (Distributed Application Specification Language)\nAction!\nActionScript\nActor\nAda\nAdenine (Haystack)\nAdvPL\nAgda\nAgilent VEE (Keysight VEE)\nAgora\nAIMMS\nAldor\nAlef\nALF\nALGOL 58\nALGOL 60\nALGOL 68\nALGOL W\nAlice (Alice ML)\nAlma-0\nAmbientTalk\nAmiga E\nAMOS (AMOS BASIC)\nAMPL\nAnalitik\nAngelScript\nApache Pig latin\nApex (Salesforce.com, Inc)\nAPL\nApp Inventor for Android's visual block language (MIT App Inventor)\nAppleScript\nAPT\nArc\nARexx\nArgus\nAssembly language (ASM)\nAutoHotkey\nAutoIt\nAutoLISP / Visual LISP\nAverest\nAWK\nAxum"

# %%
for l in languages:
    langs_letter = l.text.split("\n")  # splitting since the elements were lang1\nlang2\nlang3... in one large string rather than a string for every language. 
    langs[langs_letter[0][0]] = langs_letter  # dictionary[letter] = list_of_languages_in_that_letter
# langs = dictionary of languages per letter. ez clap.

# %%
#k:[values]                                        stage 1: creating the .csv file with all the languages.
#pd.DataFrame(d.items())
langsdf = pd.DataFrame(columns = langs.keys())
langsdf
for ch in langsdf.columns:
    langsdf[ch] = pd.Series(langs[ch])  # list of languages in ch. need to somehow put it in the column in the df. 
langsdf.fillna("null", inplace = True)
langsdf.to_csv("D:/Programming/GitHub/Projects/data/pLanguages.csv")

# %%
#codes = driver.find_elements(By.CSS_SELECTOR, 'code')
driver.quit()

# %%
# getting the questions from searching the language in stack overflow. this is used to later search those same questions, click on them, and retrieve the code lines. 
pLanguages = pd.read_csv("D:/Programming/GitHub/Projects/data/pLanguages.csv")

# %%
pLanguages
# Out:
#     Unnamed: 0                                                  A  \
# 0            0                                 A.NET (A#/A sharp)
# 1            1                                         A-0 System
# 2            2                                        A+ (A plus)
# 3            3                                                A++
# 4            4                                               ABAP
# 5            5                                                ABC
# 6            6                                          ABC ALGOL
# 7            7                                                ACC
# 8            8                          Accent (Rational Synergy)
# 9            9  Ace DASL (Distributed Application Specificatio...
# 10          10                                            Action!
# 11          11                                       ActionScript
# 12          12                                              Actor
# 13          13                                                Ada
# 14          14                                 Adenine (Haystack)
# 15          15                                              AdvPL
# 16          16                                               Agda
# 17          17                         Agilent VEE (Keysight VEE)
# 18          18                                              Agora
# 19          19                                              AIMMS
# 20          20                                              Aldor
# 21          21                                               Alef
# 22          22                                                ALF
# 23          23                                           ALGOL 58
# 24          24                                           ALGOL 60
# 25          25                                           ALGOL 68
# 26          26                                            ALGOL W
# 27          27                                   Alice (Alice ML)
# 28          28                                             Alma-0
# 29          29                                        AmbientTalk
# 30          30                                            Amiga E
# 31          31                                  AMOS (AMOS BASIC)
# 32          32                                               AMPL
# 33          33                                           Analitik
# 34          34                                        AngelScript
# 35          35                                   Apache Pig latin
# 36          36                         Apex (Salesforce.com, Inc)
# 37          37                                                APL
# 38          38  App Inventor for Android's visual block langua...
# 39          39                                        AppleScript
# 40          40                                                APT
# 41          41                                                Arc
# 42          42                                              ARexx
# 43          43                                              Argus
# 44          44                            Assembly language (ASM)
# 45          45                                         AutoHotkey
# 46          46                                             AutoIt
# 47          47                             AutoLISP / Visual LISP
# 48          48                                            Averest
# 49          49                                                AWK
# 50          50                                               Axum
#
#                               B  \
# 0                             B
# 1                       Babbage
# 2                     Ballerina
# 3                          Bash
# 4                         BASIC
# 5   Batch file (Windows/MS-DOS)
# 6         bc (basic calculator)
# 7                          BCPL
# 8                     BeanShell
# 9                      Bertrand
# 10                         BETA
# 11                        BLISS
# 12                      Blockly
# 13                        BlooP
# 14                          Boo
# 15                    Boomerang
# 16                       Bosque
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                          NaN
# 32                          NaN
# 33                          NaN
# 34                          NaN
# 35                          NaN
# 36                          NaN
# 37                          NaN
# 38                          NaN
# 39                          NaN
# 40                          NaN
# 41                          NaN
# 42                          NaN
# 43                          NaN
# 44                          NaN
# 45                          NaN
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49                          NaN
# 50                          NaN
#
#                                                     C  \
# 0                                    C – ISO/IEC 9899
# 1                                 C-- (C minus minus)
# 2                   C++ (C plus plus) – ISO/IEC 14882
# 3                                                  C*
# 4                        C# (C sharp) – ISO/IEC 23270
# 5                                                C/AL
# 6                                  Caché ObjectScript
# 7                                       C Shell (csh)
# 8                                                Caml
# 9                                              Carbon
# 10                       Cayenne (Lennart Augustsson)
# 11                                              CDuce
# 12                                              Cecil
# 13  CESIL (Computer Education in Schools Instructi...
# 14                                                Céu
# 15                                             Ceylon
# 16                                           CFEngine
# 17     Cg (High-Level Shader/Shading Language [HLSL])
# 18                                                 Ch
# 19        Chapel (Cascade High Productivity Language)
# 20                                              Charm
# 21                                              CHILL
# 22                                             CHIP-8
# 23                                              ChucK
# 24                   Cilk (also Cilk++ and Cilk plus)
# 25                                   Control Language
# 26                                             Claire
# 27                                            Clarion
# 28                                              Clean
# 29                                            Clipper
# 30                                              CLIPS
# 31                                              CLIST
# 32                                            Clojure
# 33                                                CLU
# 34                                              CMS-2
# 35                               COBOL – ISO/IEC 1989
# 36             CobolScript – COBOL Scripting language
# 37                                              Cobra
# 38                                       CoffeeScript
# 39                                         ColdFusion
# 40                                              COMAL
# 41                                              COMIT
# 42                 Common Intermediate Language (CIL)
# 43                     Common Lisp (also known as CL)
# 44                                            COMPASS
# 45                                   Component Pascal
# 46                    Constraint Handling Rules (CHR)
# 47                                            COMTRAN
# 48                                               Cool
# 49                                                Coq
# 50                                           Coral 66
#
#                                   D                                   E  \
# 0                                 D                                   E
# 1                              Dart                                Ease
# 2                            Darwin                           Easy PL/I
# 3                          DataFlex                     EASYTRIEVE PLUS
# 4                           Datalog                                  eC
# 5                        DATATRIEVE                          ECMAScript
# 6                             dBase                       Edinburgh IMP
# 7                                dc                                 EGL
# 8    DCL (DIGITAL Command Language)                              Eiffel
# 9                            Delphi                                ELAN
# 10                            DinkC                              Elixir
# 11                            DIBOL                                 Elm
# 12                              Dog                          Emacs Lisp
# 13                            Draco                             Emerald
# 14                           DRAKON                             Epigram
# 15                            Dylan     EPL (Easy Programming Language)
# 16                           DYNAMO                              Erlang
# 17  DAX (Data Analysis Expressions)                                  es
# 18                              NaN                              Escher
# 19                              NaN                               ESPOL
# 20                              NaN                             Esterel
# 21                              NaN                               Etoys
# 22                              NaN                              Euclid
# 23                              NaN                               Euler
# 24                              NaN                            Euphoria
# 25                              NaN  EusLisp Robot Programming Language
# 26                              NaN                     CMS EXEC (EXEC)
# 27                              NaN                              EXEC 2
# 28                              NaN                      Executable UML
# 29                              NaN                               Ezhil
# 30                              NaN                                 NaN
# 31                              NaN                                 NaN
# 32                              NaN                                 NaN
# 33                              NaN                                 NaN
# 34                              NaN                                 NaN
# 35                              NaN                                 NaN
# 36                              NaN                                 NaN
# 37                              NaN                                 NaN
# 38                              NaN                                 NaN
# 39                              NaN                                 NaN
# 40                              NaN                                 NaN
# 41                              NaN                                 NaN
# 42                              NaN                                 NaN
# 43                              NaN                                 NaN
# 44                              NaN                                 NaN
# 45                              NaN                                 NaN
# 46                              NaN                                 NaN
# 47                              NaN                                 NaN
# 48                              NaN                                 NaN
# 49                              NaN                                 NaN
# 50                              NaN                                 NaN
#
#                                                     F  \
# 0                                                   F
# 1                                        F# (F sharp)
# 2                                                  F*
# 3                                              Factor
# 4                                              Fantom
# 5                                               FAUST
# 6                                                 FFP
# 7                                                fish
# 8                                             Fjölnir
# 9                                                  FL
# 10                                           FlagShip
# 11                                            Flavors
# 12                                               Flex
# 13                                               Flix
# 14                                              FlooP
# 15                                    FLOW-MATIC (B0)
# 16  FOCAL (Formulating On-Line Calculations in Alg...
# 17                                              FOCUS
# 18                                               FOIL
# 19             FORMAC (FORMula MAnipulation Compiler)
# 20                                           @Formula
# 21                                              Forth
# 22                             Fortran – ISO/IEC 1539
# 23                                           Fortress
# 24                                                 FP
# 25                                     FoxBase/FoxPro
# 26                                         Franz Lisp
# 27                                            Futhark
# 28                                           F-Script
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                                     G  \
# 0                                 Game Maker Language
# 1                                   GameMonkey Script
# 2            GAMS (General Algebraic Modeling System)
# 3                                                 GAP
# 4                                              G-code
# 5                                    GDScript (Godot)
# 6                                               Genie
# 7                GDL (Geometric Description Language)
# 8                                              GEORGE
# 9                      GLSL (OpenGL Shading Language)
# 10                                              GNU E
# 11  GNU Guile (GNU Ubiquitous Intelligent Language...
# 12                                                 Go
# 13                                                Go!
# 14                 GOAL (Game Oriented Assembly Lisp)
# 15                                              Gödel
# 16                                               Golo
# 17                                 GOM (Good Old Mad)
# 18                                 Google Apps Script
# 19                                               Gosu
# 20                                  GOTRAN (IBM 1620)
# 21           GPSS (General Purpose Simulation System)
# 22          GraphTalk (Computer Sciences Corporation)
# 23                                              GRASS
# 24                                        Grasshopper
# 25                             Groovy (Apache Groovy)
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
# 50                                                NaN
#
#                                 H                            I  ...  \
# 0                            Hack                           Io  ...
# 1                          HAGGIS                         Icon  ...
# 2                           HAL/S  IBM Basic assembly language  ...
# 3   Halide (programming language)                 IBM HAScript  ...
# 4                Hamilton C shell             IBM Informix-4GL  ...
# 5                         Harbour                      IBM RPG  ...
# 6              Hartmann pipelines                          IDL  ...
# 7                         Haskell                        Idris  ...
# 8                            Haxe                       Inform  ...
# 9                          Hermes                       ISLISP  ...
# 10      High Level Assembly (HLA)                          NaN  ...
# 11                           HLSL                          NaN  ...
# 12                      Hollywood                          NaN  ...
# 13               HolyC (TempleOS)                          NaN  ...
# 14                            Hop                          NaN  ...
# 15                      Hopscotch                          NaN  ...
# 16                           Hope                          NaN  ...
# 17                           Hume                          NaN  ...
# 18                      HyperTalk                          NaN  ...
# 19                             Hy                          NaN  ...
# 20                            NaN                          NaN  ...
# 21                            NaN                          NaN  ...
# 22                            NaN                          NaN  ...
# 23                            NaN                          NaN  ...
# 24                            NaN                          NaN  ...
# 25                            NaN                          NaN  ...
# 26                            NaN                          NaN  ...
# 27                            NaN                          NaN  ...
# 28                            NaN                          NaN  ...
# 29                            NaN                          NaN  ...
# 30                            NaN                          NaN  ...
# 31                            NaN                          NaN  ...
# 32                            NaN                          NaN  ...
# 33                            NaN                          NaN  ...
# 34                            NaN                          NaN  ...
# 35                            NaN                          NaN  ...
# 36                            NaN                          NaN  ...
# 37                            NaN                          NaN  ...
# 38                            NaN                          NaN  ...
# 39                            NaN                          NaN  ...
# 40                            NaN                          NaN  ...
# 41                            NaN                          NaN  ...
# 42                            NaN                          NaN  ...
# 43                            NaN                          NaN  ...
# 44                            NaN                          NaN  ...
# 45                            NaN                          NaN  ...
# 46                            NaN                          NaN  ...
# 47                            NaN                          NaN  ...
# 48                            NaN                          NaN  ...
# 49                            NaN                          NaN  ...
# 50                            NaN                          NaN  ...
#
#                                            Q        R                 S  \
# 0   Q (programming language from Kx Systems)        R                 S
# 1        Q# (Microsoft programming language)      R++                S2
# 2                                       Qalb   Racket                S3
# 3               Quantum Computation Language     Raku            S-Lang
# 4                                   QtScript    RAPID            S-PLUS
# 5                                     QuakeC   Rapira              SA-C
# 6                                        QPL   Ratfiv         SabreTalk
# 7                                        .QL   Ratfor              SAIL
# 8                                        NaN       rc              SAKO
# 9                                        NaN   Reason               SAS
# 10                                       NaN    REBOL              SASL
# 11                                       NaN      Red            Sather
# 12                                       NaN  Redcode           Sawzall
# 13                                       NaN    REFAL             Scala
# 14                                       NaN     REXX            Scheme
# 15                                       NaN     Ring            Scilab
# 16                                       NaN     ROOP           Scratch
# 17                                       NaN      RPG        Script.NET
# 18                                       NaN      RPL               Sed
# 19                                       NaN      RSL             Seed7
# 20                                       NaN    RTL/2              Self
# 21                                       NaN     Ruby         SenseTalk
# 22                                       NaN     Rust         SequenceL
# 23                                       NaN      NaN           Serpent
# 24                                       NaN      NaN              SETL
# 25                                       NaN      NaN        Short Code
# 26                                       NaN      NaN            SIMPOL
# 27                                       NaN      NaN            SIGNAL
# 28                                       NaN      NaN            SiMPLE
# 29                                       NaN      NaN         SIMSCRIPT
# 30                                       NaN      NaN            Simula
# 31                                       NaN      NaN          Simulink
# 32                                       NaN      NaN             SISAL
# 33                                       NaN      NaN             SKILL
# 34                                       NaN      NaN              SLIP
# 35                                       NaN      NaN             SMALL
# 36                                       NaN      NaN         Smalltalk
# 37                                       NaN      NaN               SML
# 38                                       NaN      NaN        Strongtalk
# 39                                       NaN      NaN             Snap!
# 40                                       NaN      NaN  SNOBOL (SPITBOL)
# 41                                       NaN      NaN          Snowball
# 42                                       NaN      NaN               SOL
# 43                                       NaN      NaN          Solidity
# 44                                       NaN      NaN         SOPHAEROS
# 45                                       NaN      NaN            Source
# 46                                       NaN      NaN             SPARK
# 47                                       NaN      NaN         Speakeasy
# 48                                       NaN      NaN         Speedcode
# 49                                       NaN      NaN              SPIN
# 50                                       NaN      NaN              SP/k
#
#                                             T             U  \
# 0                                           T      Ubercode
# 1                                        TACL   UCSD Pascal
# 2                                      TACPOL         Umple
# 3    TADS (Text Adventure Development System)        Unicon
# 4                                         TAL       Uniface
# 5                                         Tcl         UNITY
# 6                                         Tea  UnrealScript
# 7            TECO (Text Editor and Corrector)           NaN
# 8                                     TELCOMP           NaN
# 9                                         TeX           NaN
# 10  TEX (Text Executive Programming Language)           NaN
# 11                                        TIE           NaN
# 12   TMG (TransMo Griffer), compiler-compiler           NaN
# 13                                        Tom           NaN
# 14                                        Toi           NaN
# 15                         Topspeed (Clarion)           NaN
# 16              TPU (Text Processing Utility)           NaN
# 17                                       Trac           NaN
# 18                                        TTM           NaN
# 19                       T-SQL (Transact-SQL)           NaN
# 20                      Transcript (LiveCode)           NaN
# 21  TTCN (Tree and Tabular Combined Notation)           NaN
# 22                                     Turing           NaN
# 23              TUTOR (PLATO Author Language)           NaN
# 24                                        TXL           NaN
# 25                                 TypeScript           NaN
# 26                                     Tynker           NaN
# 27                                        NaN           NaN
# 28                                        NaN           NaN
# 29                                        NaN           NaN
# 30                                        NaN           NaN
# 31                                        NaN           NaN
# 32                                        NaN           NaN
# 33                                        NaN           NaN
# 34                                        NaN           NaN
# 35                                        NaN           NaN
# 36                                        NaN           NaN
# 37                                        NaN           NaN
# 38                                        NaN           NaN
# 39                                        NaN           NaN
# 40                                        NaN           NaN
# 41                                        NaN           NaN
# 42                                        NaN           NaN
# 43                                        NaN           NaN
# 44                                        NaN           NaN
# 45                                        NaN           NaN
# 46                                        NaN           NaN
# 47                                        NaN           NaN
# 48                                        NaN           NaN
# 49                                        NaN           NaN
# 50                                        NaN           NaN
#
#                                   V                                     W  \
# 0                              Vala  WATFIV, WATFOR (WATerloo FORtran IV)
# 1                        Vim script                           WebAssembly
# 2      Viper (Ethereum/Ether (ETH))                                WebDNA
# 3                   Visual DataFlex                                Whiley
# 4               Visual DialogScript                              Winbatch
# 5                     Visual FoxPro                      Wolfram Language
# 6   Visual J++ (Visual J plus plus)                                Wyvern
# 7                       Visual LISP                                   NaN
# 8                    Visual Objects                                   NaN
# 9                     Visual Prolog                                   NaN
# 10                              NaN                                   NaN
# 11                              NaN                                   NaN
# 12                              NaN                                   NaN
# 13                              NaN                                   NaN
# 14                              NaN                                   NaN
# 15                              NaN                                   NaN
# 16                              NaN                                   NaN
# 17                              NaN                                   NaN
# 18                              NaN                                   NaN
# 19                              NaN                                   NaN
# 20                              NaN                                   NaN
# 21                              NaN                                   NaN
# 22                              NaN                                   NaN
# 23                              NaN                                   NaN
# 24                              NaN                                   NaN
# 25                              NaN                                   NaN
# 26                              NaN                                   NaN
# 27                              NaN                                   NaN
# 28                              NaN                                   NaN
# 29                              NaN                                   NaN
# 30                              NaN                                   NaN
# 31                              NaN                                   NaN
# 32                              NaN                                   NaN
# 33                              NaN                                   NaN
# 34                              NaN                                   NaN
# 35                              NaN                                   NaN
# 36                              NaN                                   NaN
# 37                              NaN                                   NaN
# 38                              NaN                                   NaN
# 39                              NaN                                   NaN
# 40                              NaN                                   NaN
# 41                              NaN                                   NaN
# 42                              NaN                                   NaN
# 43                              NaN                                   NaN
# 44                              NaN                                   NaN
# 45                              NaN                                   NaN
# 46                              NaN                                   NaN
# 47                              NaN                                   NaN
# 48                              NaN                                   NaN
# 49                              NaN                                   NaN
# 50                              NaN                                   NaN
#
#                                           X       Y                 Z
# 0   X++ (X plus plus/Microsoft Dynamics AX)  Yorick        Z notation
# 1                                       X10     YQL           Z shell
# 2                 xBase++ (xBase plus plus)    Yoix  Zebra, ZPL, ZPL2
# 3                                       XBL     NaN              Zeno
# 4            XC (targets XMOS architecture)     NaN          ZetaLisp
# 5                                  xHarbour     NaN               Zig
# 6                                        XL     NaN            Zonnon
# 7                                      Xojo     NaN              ZOPL
# 8                                     XOTcl     NaN               ZPL
# 9                                       Xod     NaN               Z++
# 10                                      XPL     NaN               NaN
# 11                                     XPL0     NaN               NaN
# 12                                   XQuery     NaN               NaN
# 13                                      XSB     NaN               NaN
# 14                              XSharp (X#)     NaN               NaN
# 15                                     XSLT     NaN               NaN
# 16                                    Xtend     NaN               NaN
# 17                                      NaN     NaN               NaN
# 18                                      NaN     NaN               NaN
# 19                                      NaN     NaN               NaN
# 20                                      NaN     NaN               NaN
# 21                                      NaN     NaN               NaN
# 22                                      NaN     NaN               NaN
# 23                                      NaN     NaN               NaN
# 24                                      NaN     NaN               NaN
# 25                                      NaN     NaN               NaN
# 26                                      NaN     NaN               NaN
# 27                                      NaN     NaN               NaN
# 28                                      NaN     NaN               NaN
# 29                                      NaN     NaN               NaN
# 30                                      NaN     NaN               NaN
# 31                                      NaN     NaN               NaN
# 32                                      NaN     NaN               NaN
# 33                                      NaN     NaN               NaN
# 34                                      NaN     NaN               NaN
# 35                                      NaN     NaN               NaN
# 36                                      NaN     NaN               NaN
# 37                                      NaN     NaN               NaN
# 38                                      NaN     NaN               NaN
# 39                                      NaN     NaN               NaN
# 40                                      NaN     NaN               NaN
# 41                                      NaN     NaN               NaN
# 42                                      NaN     NaN               NaN
# 43                                      NaN     NaN               NaN
# 44                                      NaN     NaN               NaN
# 45                                      NaN     NaN               NaN
# 46                                      NaN     NaN               NaN
# 47                                      NaN     NaN               NaN
# 48                                      NaN     NaN               NaN
# 49                                      NaN     NaN               NaN
# 50                                      NaN     NaN               NaN
#
# [51 rows x 27 columns]

# %%
# search quetsions by language from stackoverflow.
lang = 'python'
path_chrome = "D:/Programming/Python/chromedriver.exe"
url = "https://stackoverflow.com/questions/tagged/{}?tab=newest&page={}&pagesize=15".format(lang, 1)
driver = webdriver.Chrome(path_chrome)
driver.get(url)
questions = []  # want to go through all the pages to get the questions. then i want to click them one by one in the next kernel and get codes. 

page_length = int(driver.find_element(By.XPATH, '//*[@id="mainbar"]/div[7]/a[5]').text)
for i in range(10):
    try:
        qs = driver.find_elements(By.CSS_SELECTOR, 'a.s-link')
    except:
        break
        print("no data sir")
    for q in qs:
        if q.text != '' and q.text not in questions:
            questions.append(q.text)
    time.sleep(0.6)
    driver.find_element(By.LINK_TEXT, 'Next').click()
    time.sleep(0.5)
questions
# Out:
# C:\Users\Itamar\AppData\Local\Temp\ipykernel_10876\3981507611.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path_chrome)
# ['Add new line after every Nth word without using for loop',
#  'How to fetch data from Odoo to react native?',
#  'unbale to replace method in python',
#  'result for print(5*2*3.14) is wrong in Python [duplicate]',
#  'Extract info from a bullet list text in python',
#  'how to convert ISO 8601 to Date time(Utc) in Python',
#  'frozenset and tuple inside itself',
#  'How can I change the format of a JSON output from iterating through a python dictionary',
#  'Python cx_oracle executemany how many rows insert into DB',
#  'Kafka container connecting from inside the container and outside using the same hostname',
#  'Python - if statement application question [closed]',
#  'break the loop when list len reaches to 5 (In for loop)',
#  'What is the python-poetry config file after 1.2.0 release?',
#  'How to map word vector to the most similar/closest word using spaCy for multiple words?',
#  'How to write a mastermind game [closed]',
#  'Hot Network Questions',
#  'Inheritance of OptaPy planning_entitiy classes?',
#  'The Problem of Multiple Threads for Sqlite3 - got an unexpected result',
#  'cs50p grader not accepting fuel test',
#  "Error loading gensim's TidfModel. No such file or directory: /tmp/simserver893b90.0'",
#  'TensorFlow results are not reproducible while the global seed is set - Python - Tensorflow - MacOS M1',
#  'Python key exist or not?',
#  'How to make next tkinter messageboxes doesnt show only when pressing ok',
#  'Conflict in stdout of the subprocess.run() command in multi-thread projects',
#  'Why does QProcess returns Starting state even after killing the process?',
#  'Got a problem when try deploy machine learning model run in website',
#  'Python Pandas - Replacing cell value matching regular expression',
#  'Convert 2D input array to 2D list directly using inbuilt function',
#  'How to sort this dictionary properly?',
#  'How to slice every first 3 values for every 50 value in an array',
#  'Does Lua have an equivalent of Pythons exec() function?',
#  'python 2 script to python 3 conversion: error: map object is not a subscriptable [duplicate]',
#  "Sqlite3 | AUTOINCREMENT won't increment id",
#  'How to make a loop continue to next entry when encountering RuntimeError',
#  'How to make snscrape faster?',
#  'Why do I need to change the frequency for accessing a dataframe indexed with DatetimeIndex in Pandas?',
#  'difference between in and get in python [duplicate]',
#  "'utf-8' codec can't decode byte 0x8b in position 0: invalid start byte django",
#  'How to extract only the text without <h1> tags in python using beautifulsoup? [duplicate]',
#  'How to change the type of data from [[, , , ,]] to [[],[],[]]?',
#  'is there a way in python for creating pages like word which will work on same window and have diffrent pages [closed]',
#  'Python multiprocessing uses all cores even when limited',
#  'How to get JSON data between specific date ranges in Python?',
#  'customize color of bar chart based on value in plotly',
#  'Are there any books for machine learning with Python without any scikit-learn or TensorFlow? [closed]',
#  'What are the best ways to pass variable to a C++ code from Python? [closed]',
#  "Python Django - unsupported operand type(s) for -: 'float' and 'NoneType'",
#  'The TA-Lib and IQoptionapi is Not Working',
#  'Defining global variables for a python package',
#  'Strategies to run user-submitted code on AWS',
#  'Return a random set of words from system dictionary that meet specific criteria',
#  'How can I change my Python code to make merge sort works? [closed]',
#  'how to make a countdown label that start after i press button kivy',
#  'Matplotlib 3D scatter plot animation not moving',
#  'Problems with pygame collisions',
#  'HTTP error 400 & TypeError: not all arguments converted during string formatting [duplicate]',
#  "sqlite3 | data doesn't save in table",
#  'How do we run multiple services of a single FastAPI application from single script/command',
#  'How can i fix pyAudio import on termux',
#  'How can I generate a new string using the same function? (tkinter, python)',
#  'Using scikit to mask image segmentation to decrease background and boundary',
#  'Getting a HTTP response body 400 error when doing a post request on an api',
#  'Difference in refer and parameter expansion [closed]',
#  "AttributeError: module 'pandas' has no attribute 'series' or 'read' [closed]",
#  'extract text lines between two lines with text marks using regex',
#  'Python Kivy Image has unwanted padding',
#  'How to make a regex pattern? Python',
#  "Can't Read data from spreadsheets",
#  'Tkinter - Key bind not responding [duplicate]',
#  'How to iterate through all the objects of a specific class in python? [duplicate]',
#  'Python selenium facebook checkpoint',
#  'How can I scrape an apple HTML page using python?',
#  'torch.cuda.is_available returns false when using ssh remote debugging',
#  'Uwsgi Locking Up After a Few Requests with Nginx/Traefik/Flask App Running over HTTPS/TLS and Docker',
#  'Pandas join rows of text and output as a new variable',
#  'applying skip connections for pre-trained vgg19 in keras',
#  'How do I go about fixing this? [closed]',
#  'Pulling data from application life cycle management and sending to sharepoint using python script what procedure has to follow',
#  'Program to calculate the area of the signal that appears simultaneously on 8 channels',
#  "unsupported operand type(s) for -: 'list' and 'float'",
#  "No module named 'admin_ordering' even after pip install admin_ordering in venv and it shows in /venv/lib/",
#  'chromedriver auto installer in AWS Batch',
#  'Datetime to Time/HH:MM format – investigating events on multiple dates by the time of day',
#  'How to open an IP camera on streamlit webapp?',
#  "Problem module ''x'' has no attribue ''y'' in my first CRUD with Python",
#  'How to take multiple inputs from the same input field and display each value individually?',
#  'Efficiently imprint an array onto another in Python',
#  "how do i fix this? i'm not getting the right value for sarah",
#  'Convert string list values of dictionary into ranked integers, but with their ranks + 1 and descending',
#  'type(x) is list vs type(x) == list',
#  'Problems when trying to create a QR code encoder',
#  'Python how to know properties/methods of objects',
#  'current_user NoneType error when used outside a route [duplicate]',
#  'How do I play a video on display in background for pygame? [duplicate]',
#  'The prediction of my resnet50 model for different images is only one. why is it?',
#  'How to add User Input (String) into a list?',
#  'Remove square brackets and commas in an array on requests.get pastebin url and paste it on a file',
#  'Fixing a NoReverseMatch Error for a Django Project',
#  'How to get users activity and status using discord api in python',
#  'Why my multiprocessing pool is not working? Python',
#  '“tests/functional/test_install.py::test_install_using_install_option_and_editable” test run failed',
#  'How to attach an image in Jupyter Notebook without keeping the file in the same directory?',
#  'what is the wrong in this python script? [closed]',
#  'Lambda function in another function',
#  "Is there a way to make the json.load() function not produce an error if there's an extra command in a json file?",
#  'Detecting numbers from a segmented image',
#  'Pytest doest not see @pytest.fixture',
#  'No module named "panel. pane\'; \'panel\' is not a package',
#  'newbie mistake in discord bot',
#  'How do I update the value of text in a .kv file while time.sleep is running in python?',
#  'Is it safe to kill the Python process when writing to a file?',
#  'Matplotlib Line Chart Not Plotting Correctly',
#  'Is there a way to check for compile errors from running gcc inside python?',
#  '(Python TK) After using askopenfilename, I am unable to enter data into Entry or Combobox widget',
#  'How to add together elements in a tuple?',
#  'Increment index in for loop only if condition met',
#  'python3 match everything before CVE',
#  'API_KEY not set in pythonanywhere flask project',
#  "Can't plot Scatterplot in Python",
#  'Assign class to a sample in Python',
#  'Removing word from string returns nan in dataframe',
#  'How do I create a web app in python based on csv data? [closed]',
#  'Creating an SQLAlchemy engine based on psycopg3',
#  'i want to try to separate the 2 inputs and i want to also input them with different positions',
#  'confluent_kafka python error "Unsupported value "SASL_SSL" for configuration property "security.protocol": OpenSSL not available at build time"}',
#  'python multiple threads redirecting stdout',
#  'Python instock Bot - how to tell python if text is shown on website to do something',
#  "Change background colour from one column based on other column's value in Streamlit and Ag-Grid",
#  'Problems installing IRAF in Intel Macbook',
#  "Can't set user.is_active and user.is_admin to True",
#  'Getting a range of numbers with recursion using python',
#  'Sumproduct of a continuous function in python',
#  '_tkinter.TclError: can\'t invoke "tk_messageBox" command: application has been destroyed',
#  "Why can't my matplotlib import in more than one file [closed]",
#  'How to convert an array of objects to object of objects in python [closed]',
#  'Python moving and deleting elements in a dictionary',
#  'Making a python script that blocks websites during a focus period without asking for elevated privileges in windows',
#  'how can i solve this problem couldnot open logo from this such directory? [duplicate]',
#  'Multiple URLs Web Scraping',
#  'Unable to get a decision boundary visualisation for a multi-class SCG in python',
#  'How to ignore RuntimeError: Bad password for file <filename>',
#  'Python rolling uncentered pearson correlation for high dimensional signals',
#  "I'm trying to get started in python, and I want to make an image appear on screen [closed]",
#  'How do I make self.ids give the correct value in kivy?',
#  'How can I insert a single value into a Pandas dataframe at a given location? [duplicate]',
#  'regex split: ignore delimiter if followed by short substring',
#  'Creating a matrix of routes using distance values in two columns',
#  'Using regex, how to remove a substring which occures multiple times?',
#  'Pandas drop row if column value has appeared more than some number of times depending on the value',
#  'convert string into hex in python [duplicate]',
#  'APScheduler BackgroundScheduler() run only once in deploy while running perfectly in localhost']

# %%
# stage 2: collecting questions from each language in the csv.
for i in range(450):
    try:
        qs = driver.find_elements(By.CSS_SELECTOR, 'a.s-link')
    except:
        break
        print("no data sir")
    for q in qs:
        if q.text != '' and q.text not in questions:
            questions.append(q.text)
    time.sleep(0.6)
    driver.find_element(By.LINK_TEXT, 'Next').click()
    time.sleep(0.5)

# %%
# searching for java while i go do stuff
lang = 'java'
path_chrome = "D:/Programming/Python/chromedriver.exe"
url = "https://stackoverflow.com/questions/tagged/{}?tab=newest&page={}&pagesize=15".format(lang, 1)
driver = webdriver.Chrome(path_chrome)
driver.get(url)
questions_java = []  # want to go through all the pages to get the questions. then i want to click them one by one in the next kernel and get codes. 

page_length = int(driver.find_element(By.XPATH, '//*[@id="mainbar"]/div[7]/a[5]').text)
for i in range(500):
    try:
        qs = driver.find_elements(By.CSS_SELECTOR, 'a.s-link')
    except:
        break
        print("no data sir")
    for q in qs:
        if q.text != '' and q.text not in questions_java:
            questions_java.append(q.text)
    time.sleep(0.6)
    driver.find_element(By.LINK_TEXT, 'Next').click()
    time.sleep(0.5)
# Out:
# C:\Users\Itamar\AppData\Local\Temp\ipykernel_10876\2528097711.py:5: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(path_chrome)
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [248], in <cell line: 10>()
#      18         questions_java.append(q.text)
#      19 time.sleep(0.6)
# ---> 20 driver.find_element(By.LINK_TEXT, 'Next').click()
#      21 time.sleep(0.5)
#
# File c:\users\itamar\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:1251, in WebDriver.find_element(self, by, value)
#    1248     by = By.CSS_SELECTOR
#    1249     value = '[name="%s"]' % value
# -> 1251 return self.execute(Command.FIND_ELEMENT, {
#    1252     'using': by,
#    1253     'value': value})['value']
#
# File c:\users\itamar\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File c:\users\itamar\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"link text","selector":"Next"}
#   (Session info: chrome=104.0.5112.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010278B3+2193587]
# 	Ordinal0 [0x00FC0681+1771137]
# 	Ordinal0 [0x00ED41A8+803240]
# 	Ordinal0 [0x00F024A0+992416]
# 	Ordinal0 [0x00F0273B+993083]
# 	Ordinal0 [0x00F2F7C2+1177538]
# 	Ordinal0 [0x00F1D7F4+1103860]
# 	Ordinal0 [0x00F2DAE2+1170146]
# 	Ordinal0 [0x00F1D5C6+1103302]
# 	Ordinal0 [0x00EF77E0+948192]
# 	Ordinal0 [0x00EF86E6+952038]
# 	GetHandleVerifier [0x012D0CB2+2738370]
# 	GetHandleVerifier [0x012C21B8+2678216]
# 	GetHandleVerifier [0x010B17AA+512954]
# 	GetHandleVerifier [0x010B0856+509030]
# 	Ordinal0 [0x00FC743B+1799227]
# 	Ordinal0 [0x00FCBB68+1817448]
# 	Ordinal0 [0x00FCBC55+1817685]
# 	Ordinal0 [0x00FD5230+1856048]
# 	BaseThreadInitThunk [0x7577FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76EF7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76EF7A6E+238]

# %%
# pd.DataFrame(pd.Series(questions), columns = {'python'}).to_csv("D:/Programming/GitHub/Projects/data/py_qs.csv")  #converting the list of questions into a csv file.

# %%
pd.DataFrame(pd.Series(questions_java), columns = {'java'}).to_csv("D:/Programming/GitHub/Projects/data/java_qs.csv")

# %%
# searching the questions and retrieving the code lines
lang = 'python'
path_chrome = "D:/Programming/Python/chromedriver.exe"
url = "https://stackoverflow.com/"
driver = webdriver.Chrome(path_chrome)
driver.get(url)
questions[0]
search = driver.find_element(By.XPATH, '//*[@id="search"]/div/input')
search.send_keys(questions[0])
driver.send_keys(Keys.RETURN)

# %%
questions[0]
# Out:
# 'Add new line after every Nth word without using for loop'

# %%
# at this point, you have all the questions you need in a list. what you want now is to search each one, and take the lines of code.

# %%
# qs = driver.find_elements(By.CSS_SELECTOR, 'a.s-link')
driver.quit()

# %%
questions_codes = {}

# get list of all questions from page. after you retrieve the list, save it in a dictionary of pages and move to the next page.
for q in qs:
    driver.get("https://stackoverflow.com")  # goes back to the default page for a search. may be unnecessary since you have a searchbar still within each question page. 
    
    searchbar = driver.get_element(By.ID, 'search')
    time.sleep(0.4)
    questions_codes[q.text] = driver.find_elements(By.CSS_SELECTOR, 'code')  # making the dictionary formatted {questiontext:[code1, code2, code3]}
    time.sleep(0.5)
    driver.quit()
    time.sleep(0.5)
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Input In [116], in <cell line: 1>()
# ----> 1 qs = driver.find_elements(By.CSS_SELECTOR, 'a.s-link')
#       2 questions_codes = {}
#       5 for q in qs:
#
# File c:\users\itamar\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:1284, in WebDriver.find_elements(self, by, value)
#    1280     value = '[name="%s"]' % value
#    1282 # Return empty list if driver returns null
#    1283 # See https://github.com/SeleniumHQ/selenium/issues/4555
# -> 1284 return self.execute(Command.FIND_ELEMENTS, {
#    1285     'using': by,
#    1286     'value': value})['value'] or []
#
# File c:\users\itamar\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\webdriver.py:430, in WebDriver.execute(self, driver_command, params)
#     428 response = self.command_executor.execute(driver_command, params)
#     429 if response:
# --> 430     self.error_handler.check_response(response)
#     431     response['value'] = self._unwrap_value(
#     432         response.get('value', None))
#     433     return response
#
# File c:\users\itamar\appdata\local\programs\python\python39\lib\site-packages\selenium\webdriver\remote\errorhandler.py:247, in ErrorHandler.check_response(self, response)
#     245         alert_text = value['alert'].get('text')
#     246     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 247 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: chrome not reachable
#   (Session info: chrome=104.0.5112.102)
# Stacktrace:
# Backtrace:
# 	Ordinal0 [0x010278B3+2193587]
# 	Ordinal0 [0x00FC0681+1771137]
# 	Ordinal0 [0x00ED4070+802928]
# 	Ordinal0 [0x00EC9AB2+760498]
# 	Ordinal0 [0x00EBCEAF+708271]
# 	Ordinal0 [0x00EC1142+725314]
# 	Ordinal0 [0x00EC55C9+742857]
# 	Ordinal0 [0x00ED5500+808192]
# 	Ordinal0 [0x00F2D2C2+1168066]
# 	Ordinal0 [0x00F1D5C6+1103302]
# 	Ordinal0 [0x00EF77E0+948192]
# 	Ordinal0 [0x00EF86E6+952038]
# 	GetHandleVerifier [0x012D0CB2+2738370]
# 	GetHandleVerifier [0x012C21B8+2678216]
# 	GetHandleVerifier [0x010B17AA+512954]
# 	GetHandleVerifier [0x010B0856+509030]
# 	Ordinal0 [0x00FC743B+1799227]
# 	Ordinal0 [0x00FCBB68+1817448]
# 	Ordinal0 [0x00FCBC55+1817685]
# 	Ordinal0 [0x00FD5230+1856048]
# 	BaseThreadInitThunk [0x7577FA29+25]
# 	RtlGetAppContainerNamedObjectPath [0x76EF7A9E+286]
# 	RtlGetAppContainerNamedObjectPath [0x76EF7A6E+238]

# %%
# consider just runnning over all questions in stack overflow and based on their tags put them in a dictionary for their language. that could save some time with doing this process for every language, 
# but it could also be more costly as it would have to classify based on a shit ton of tags. sometimes "error-handling, shutil, jinja2", all useless bullshit that aren't really languages. 
# plan your database.
